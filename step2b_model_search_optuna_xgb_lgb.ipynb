# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder, KBinsDiscretizer, StandardScaler, MinMaxScaler, FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score

from imblearn.over_sampling import RandomOverSampler, SMOTE, SMOTENC
from imblearn.pipeline import Pipeline as imb_pipeline
from category_encoders.target_encoder import TargetEncoder

import lightgbm as lgb
import xgboost as xgb
import optuna
from optuna.integration import LightGBMPruningCallback

import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None

# %matplotlib inline
# Out:
# /Users/dorukcanga/opt/anaconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # Read Data

# %%
train_data = pd.read_pickle('./data/train_file_eng.pkl')

# %%
train_data.head(1)
# Out:
#    age          job  marital education  default housing loan   contact month  \
# 0   49  blue-collar  married  basic.9y  unknown      no   no  cellular   nov
#
#   day_of_week  duration  campaign  previous     poutcome   y  y_encoded  \
# 0         wed       227         4         0  nonexistent  no          0
#
#   quarter
# 0      q4

# %%
train_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'poutcome', 'y', 'y_encoded', 'quarter'],
#       dtype='object')

# %%
feature_set = ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
               'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
               'poutcome', 'quarter']

cat_features = ['job', 'marital', 'education', 'default', 'housing', 'loan',
                'contact', 'month', 'day_of_week', 'poutcome', 'quarter']

num_features = ['age', 'duration', 'campaign', 'previous']

# %%
for col_name in cat_features:
    train_data[col_name] = train_data[col_name].astype('category')

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data[feature_set], train_data.y_encoded, random_state=24, test_size=0.2)

# %%
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
X_train.shape, X_test.shape
# Out:
# ((26328, 15), (6582, 15))

# %% [markdown]
# # Hyperparameter Tuning with Optuna

# %% [markdown]
# ## LightGBM

# %%
def lgbm_objective(trial, X, y, oversampling=None, sampling_strategy=None):
    
    #Param Grid for Lightgbm
    param_grid = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=50),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.5, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 80),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "min_child_samples": trial.suggest_int("min_child_samples", 20, 200, step=20),
        "reg_alpha": trial.suggest_int("reg_alpha", 0, 10),
        "reg_lambda": trial.suggest_int("reg_lambda", 0, 10),
        #"min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1),
    }
    
    #Cross Validation with StratifiedKFold
    scores = []
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
    for train_idx, test_idx in cv.split(X, y):
        X_train_fold, X_test_fold = X.iloc[train_idx], X.iloc[test_idx]
        y_train_fold, y_test_fold = y[train_idx], y[test_idx]
        
        if oversampling == 'random':
            sampler = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=24)
            X_train_fold2, y_train_fold2 = sampler.fit_resample(X_train_fold, y_train_fold)
        elif oversampling == 'smote':
            categorical_features = np.array([idx for idx, col_name in enumerate(X_train_fold.columns) if col_name in cat_features])
            sampler = SMOTENC(categorical_features = categorical_features)
            X_train_fold2, y_train_fold2 = sampler.fit_resample(X_train_fold, y_train_fold)
        else:
            X_train_fold2, y_train_fold2 = X_train_fold, y_train_fold
        
        model = lgb.LGBMClassifier(objective="binary",
                                   subsample_freq=1,
                                   verbosity=-1,
                                   random_state=24,
                                   n_jobs=4, **param_grid)
        
        if oversampling == 'class_weight':
            model.set_params(class_weight='balanced')
        
        model.fit(
            X_train_fold2,
            y_train_fold2,
            eval_set=[(X_test_fold, y_test_fold)],
            eval_metric="auc",
            early_stopping_rounds=100,
            callbacks=[LightGBMPruningCallback(trial, "auc")],
            verbose=-1
        )
        
        y_preds_fold = model.predict_proba(X_test_fold)
        y_preds_fold = [i[1] for i in y_preds_fold]
        fold_score = roc_auc_score(y_test_fold, y_preds_fold)
        scores.append(fold_score)
        
    return np.mean(scores)

# %% [markdown]
# ### SMOTENC

# %%
study = optuna.create_study(direction="maximize", study_name="LGBM")
func = lambda trial: lgbm_objective(trial, X_train, y_train, oversampling='smote', sampling_strategy='auto')
study.optimize(func, n_trials=30)
# Out:
# [I 2022-04-05 23:02:59,091] A new study created in memory with name: LGBM
# [I 2022-04-05 23:03:14,860] Trial 0 finished with value: 0.9128077316698056 and parameters: {'n_estimators': 800, 'learning_rate': 0.1058184329107983, 'num_leaves': 35, 'max_depth': 7, 'min_child_samples': 180, 'lambda_l1': 4, 'lambda_l2': 2, 'bagging_fraction': 0.7582908996248414, 'feature_fraction': 0.9093827675566161}. Best is trial 0 with value: 0.9128077316698056.
# [I 2022-04-05 23:03:30,137] Trial 1 finished with value: 0.9126150842926286 and parameters: {'n_estimators': 850, 'learning_rate': 0.2070726960639668, 'num_leaves': 78, 'max_depth': 9, 'min_child_samples': 80, 'lambda_l1': 2, 'lambda_l2': 2, 'bagging_fraction': 0.8629888312976537, 'feature_fraction': 0.659007558688024}. Best is trial 0 with value: 0.9128077316698056.
# [I 2022-04-05 23:03:45,208] Trial 2 finished with value: 0.9099178759652553 and parameters: {'n_estimators': 800, 'learning_rate': 0.12581725124950335, 'num_leaves': 42, 'max_depth': 3, 'min_child_samples': 160, 'lambda_l1': 2, 'lambda_l2': 0, 'bagging_fraction': 0.6827772582896989, 'feature_fraction': 0.7857550064044672}. Best is trial 0 with value: 0.9128077316698056.
# [I 2022-04-05 23:04:00,264] Trial 3 finished with value: 0.9111352686203904 and parameters: {'n_estimators': 150, 'learning_rate': 0.028247057662800057, 'num_leaves': 67, 'max_depth': 6, 'min_child_samples': 100, 'lambda_l1': 10, 'lambda_l2': 4, 'bagging_fraction': 0.8759481461030749, 'feature_fraction': 0.5197026155888413}. Best is trial 0 with value: 0.9128077316698056.
# [I 2022-04-05 23:04:16,281] Trial 4 finished with value: 0.9126770624616498 and parameters: {'n_estimators': 250, 'learning_rate': 0.06080074484238723, 'num_leaves': 62, 'max_depth': 8, 'min_child_samples': 200, 'lambda_l1': 10, 'lambda_l2': 1, 'bagging_fraction': 0.6470364324831135, 'feature_fraction': 0.9216587541624457}. Best is trial 0 with value: 0.9128077316698056.
# [I 2022-04-05 23:04:19,369] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:04:22,151] Trial 6 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:04:24,848] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:04:27,373] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:04:29,984] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:04:43,965] Trial 10 pruned. Trial was pruned at iteration 130.
# [I 2022-04-05 23:04:46,655] Trial 11 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:04:49,193] Trial 12 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:04:52,042] Trial 13 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:04:55,021] Trial 14 pruned. Trial was pruned at iteration 54.
# [I 2022-04-05 23:04:57,922] Trial 15 pruned. Trial was pruned at iteration 1.
# [I 2022-04-05 23:05:14,056] Trial 16 finished with value: 0.9132129337007994 and parameters: {'n_estimators': 700, 'learning_rate': 0.18481492933743468, 'num_leaves': 48, 'max_depth': 8, 'min_child_samples': 180, 'lambda_l1': 5, 'lambda_l2': 4, 'bagging_fraction': 0.597383787617114, 'feature_fraction': 0.6812948885609278}. Best is trial 16 with value: 0.9132129337007994.
# [I 2022-04-05 23:05:16,709] Trial 17 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:05:31,903] Trial 18 finished with value: 0.9132617431062728 and parameters: {'n_estimators': 1000, 'learning_rate': 0.24387386507247102, 'num_leaves': 35, 'max_depth': 10, 'min_child_samples': 120, 'lambda_l1': 4, 'lambda_l2': 10, 'bagging_fraction': 0.7380959627561593, 'feature_fraction': 0.7329585642050365}. Best is trial 18 with value: 0.9132617431062728.
# [I 2022-04-05 23:05:34,920] Trial 19 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:05:37,684] Trial 20 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:05:40,209] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:05:55,664] Trial 22 finished with value: 0.91330546869999 and parameters: {'n_estimators': 900, 'learning_rate': 0.1416544857775018, 'num_leaves': 36, 'max_depth': 8, 'min_child_samples': 140, 'lambda_l1': 6, 'lambda_l2': 4, 'bagging_fraction': 0.7402790033178102, 'feature_fraction': 0.7431748265589735}. Best is trial 22 with value: 0.91330546869999.
# [I 2022-04-05 23:06:10,805] Trial 23 finished with value: 0.9133965671454625 and parameters: {'n_estimators': 900, 'learning_rate': 0.1488053774145398, 'num_leaves': 38, 'max_depth': 9, 'min_child_samples': 120, 'lambda_l1': 7, 'lambda_l2': 5, 'bagging_fraction': 0.7138835037910843, 'feature_fraction': 0.7377520560348833}. Best is trial 23 with value: 0.9133965671454625.
# [I 2022-04-05 23:06:13,834] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:06:16,388] Trial 25 pruned. Trial was pruned at iteration 2.
# [I 2022-04-05 23:06:18,923] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:06:34,393] Trial 27 finished with value: 0.9126156804007449 and parameters: {'n_estimators': 900, 'learning_rate': 0.24355260711142615, 'num_leaves': 40, 'max_depth': 10, 'min_child_samples': 120, 'lambda_l1': 8, 'lambda_l2': 7, 'bagging_fraction': 0.7353644527151421, 'feature_fraction': 0.7252368921642586}. Best is trial 23 with value: 0.9133965671454625.
# [I 2022-04-05 23:06:37,317] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2022-04-05 23:06:53,303] Trial 29 finished with value: 0.9135864870089897 and parameters: {'n_estimators': 800, 'learning_rate': 0.12341671430038074, 'num_leaves': 36, 'max_depth': 8, 'min_child_samples': 140, 'lambda_l1': 3, 'lambda_l2': 3, 'bagging_fraction': 0.7529972592967441, 'feature_fraction': 0.7877978799484263}. Best is trial 29 with value: 0.9135864870089897.

# %% [markdown]
# ### Random Over Sampling

# %%
study2 = optuna.create_study(direction="maximize", study_name="LGBM2")
func = lambda trial: lgbm_objective(trial, X_train, y_train, oversampling='random', sampling_strategy='auto')
study2.optimize(func, n_trials=30)
# Out:
# [I 2022-04-06 00:33:24,634] A new study created in memory with name: LGBM2
# [I 2022-04-06 00:33:28,318] Trial 0 finished with value: 0.9306547093600928 and parameters: {'n_estimators': 900, 'learning_rate': 0.023392417406422665, 'num_leaves': 40, 'max_depth': 7, 'min_child_samples': 140, 'reg_alpha': 4, 'reg_lambda': 2, 'subsample': 0.9598618663408268, 'colsample_bytree': 0.7843708215804357}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:30,811] Trial 1 finished with value: 0.9276731600134343 and parameters: {'n_estimators': 400, 'learning_rate': 0.4849014641515901, 'num_leaves': 68, 'max_depth': 2, 'min_child_samples': 140, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.7565852858741953, 'colsample_bytree': 0.5405909863633254}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:34,067] Trial 2 finished with value: 0.9302920479376608 and parameters: {'n_estimators': 600, 'learning_rate': 0.04703333021404924, 'num_leaves': 78, 'max_depth': 4, 'min_child_samples': 120, 'reg_alpha': 2, 'reg_lambda': 10, 'subsample': 0.6466838182020264, 'colsample_bytree': 0.7592296063875132}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:37,654] Trial 3 finished with value: 0.927494707058204 and parameters: {'n_estimators': 500, 'learning_rate': 0.01115359703558816, 'num_leaves': 33, 'max_depth': 4, 'min_child_samples': 180, 'reg_alpha': 7, 'reg_lambda': 10, 'subsample': 0.6104971390889353, 'colsample_bytree': 0.7018759670761471}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:43,457] Trial 4 finished with value: 0.93052606053917 and parameters: {'n_estimators': 550, 'learning_rate': 0.010961633934505664, 'num_leaves': 27, 'max_depth': 8, 'min_child_samples': 20, 'reg_alpha': 1, 'reg_lambda': 5, 'subsample': 0.5848313444276838, 'colsample_bytree': 0.5500793886661962}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:43,548] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:45,603] Trial 6 finished with value: 0.9272037137518625 and parameters: {'n_estimators': 750, 'learning_rate': 0.21443277719073628, 'num_leaves': 76, 'max_depth': 9, 'min_child_samples': 20, 'reg_alpha': 3, 'reg_lambda': 1, 'subsample': 0.7211924192464858, 'colsample_bytree': 0.5028502438505622}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:47,445] Trial 7 finished with value: 0.9274866625761374 and parameters: {'n_estimators': 500, 'learning_rate': 0.29275429565973043, 'num_leaves': 55, 'max_depth': 10, 'min_child_samples': 180, 'reg_alpha': 3, 'reg_lambda': 3, 'subsample': 0.6904464293505886, 'colsample_bytree': 0.5526549353844602}. Best is trial 0 with value: 0.9306547093600928.
# [I 2022-04-06 00:33:47,547] Trial 8 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:33:48,961] Trial 9 finished with value: 0.9307875778486816 and parameters: {'n_estimators': 100, 'learning_rate': 0.11333569688388861, 'num_leaves': 19, 'max_depth': 7, 'min_child_samples': 80, 'reg_alpha': 4, 'reg_lambda': 0, 'subsample': 0.5170860303134346, 'colsample_bytree': 0.7029693318019654}. Best is trial 9 with value: 0.9307875778486816.
# [I 2022-04-06 00:33:49,081] Trial 10 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:49,229] Trial 11 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:33:51,486] Trial 12 finished with value: 0.9298754072542591 and parameters: {'n_estimators': 150, 'learning_rate': 0.024970715056968337, 'num_leaves': 43, 'max_depth': 7, 'min_child_samples': 140, 'reg_alpha': 0, 'reg_lambda': 4, 'subsample': 0.8354905818236884, 'colsample_bytree': 0.8355800645736127}. Best is trial 9 with value: 0.9307875778486816.
# [I 2022-04-06 00:33:51,601] Trial 13 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:33:51,732] Trial 14 pruned. Trial was pruned at iteration 9.
# [I 2022-04-06 00:33:51,856] Trial 15 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:33:51,979] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:52,113] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:52,270] Trial 18 pruned. Trial was pruned at iteration 9.
# [I 2022-04-06 00:33:52,409] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:52,542] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:52,667] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:52,857] Trial 22 pruned. Trial was pruned at iteration 35.
# [I 2022-04-06 00:33:52,985] Trial 23 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:33:53,118] Trial 24 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:33:53,236] Trial 25 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:33:53,353] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:53,480] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:33:53,606] Trial 28 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:33:53,726] Trial 29 pruned. Trial was pruned at iteration 0.

# %% [markdown]
# ### Class Weight Hyperparameter

# %%
study3 = optuna.create_study(direction="maximize", study_name="LGBM3")
func = lambda trial: lgbm_objective(trial, X_train, y_train, oversampling='class_weight', sampling_strategy=None)
study3.optimize(func, n_trials=30)
# Out:
# [I 2022-04-06 00:33:53,731] A new study created in memory with name: LGBM3
# [I 2022-04-06 00:33:55,445] Trial 0 finished with value: 0.9270814700853041 and parameters: {'n_estimators': 200, 'learning_rate': 0.010909359392112279, 'num_leaves': 35, 'max_depth': 9, 'min_child_samples': 60, 'reg_alpha': 0, 'reg_lambda': 4, 'subsample': 0.5163220427230086, 'colsample_bytree': 0.9583240118432258}. Best is trial 0 with value: 0.9270814700853041.
# [I 2022-04-06 00:34:01,647] Trial 1 finished with value: 0.9306633700636073 and parameters: {'n_estimators': 800, 'learning_rate': 0.010264924032798212, 'num_leaves': 36, 'max_depth': 10, 'min_child_samples': 20, 'reg_alpha': 5, 'reg_lambda': 5, 'subsample': 0.7299734822446494, 'colsample_bytree': 0.7839975374619017}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:03,301] Trial 2 finished with value: 0.9284524643675857 and parameters: {'n_estimators': 800, 'learning_rate': 0.24125462551108093, 'num_leaves': 64, 'max_depth': 2, 'min_child_samples': 200, 'reg_alpha': 9, 'reg_lambda': 3, 'subsample': 0.8132889473734474, 'colsample_bytree': 0.8420296547397419}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:04,890] Trial 3 finished with value: 0.9301836610199807 and parameters: {'n_estimators': 200, 'learning_rate': 0.06083063295757772, 'num_leaves': 46, 'max_depth': 7, 'min_child_samples': 100, 'reg_alpha': 3, 'reg_lambda': 6, 'subsample': 0.6575144614918267, 'colsample_bytree': 0.8020131597622462}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:06,979] Trial 4 finished with value: 0.9281490736530916 and parameters: {'n_estimators': 700, 'learning_rate': 0.09338010085990098, 'num_leaves': 59, 'max_depth': 3, 'min_child_samples': 120, 'reg_alpha': 5, 'reg_lambda': 5, 'subsample': 0.5162935604174559, 'colsample_bytree': 0.8211579341734623}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:07,018] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:07,061] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:07,099] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:07,141] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:08,350] Trial 9 finished with value: 0.9283446357012064 and parameters: {'n_estimators': 650, 'learning_rate': 0.1747317709149259, 'num_leaves': 34, 'max_depth': 10, 'min_child_samples': 100, 'reg_alpha': 6, 'reg_lambda': 0, 'subsample': 0.5896936665576673, 'colsample_bytree': 0.7849226289252559}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:08,415] Trial 10 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:34:08,482] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:08,545] Trial 12 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:09,743] Trial 13 finished with value: 0.9268441725695589 and parameters: {'n_estimators': 350, 'learning_rate': 0.437909447112781, 'num_leaves': 50, 'max_depth': 10, 'min_child_samples': 160, 'reg_alpha': 4, 'reg_lambda': 2, 'subsample': 0.7611348983217753, 'colsample_bytree': 0.8378448486306034}. Best is trial 1 with value: 0.9306633700636073.
# [I 2022-04-06 00:34:09,806] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:09,870] Trial 15 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:09,937] Trial 16 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:34:10,002] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,068] Trial 18 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,136] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,200] Trial 20 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,267] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,330] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,393] Trial 23 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,457] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,523] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,591] Trial 26 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:34:10,654] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,715] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:10,781] Trial 29 pruned. Trial was pruned at iteration 0.

# %% [markdown]
# ### No Oversampling

# %%
study4 = optuna.create_study(direction="maximize", study_name="LGBM3")
func = lambda trial: lgbm_objective(trial, X_train, y_train, oversampling=None, sampling_strategy=None)
study4.optimize(func, n_trials=30)
# Out:
# [I 2022-04-06 00:34:10,786] A new study created in memory with name: LGBM3
# [I 2022-04-06 00:34:11,977] Trial 0 finished with value: 0.9292895357302416 and parameters: {'n_estimators': 200, 'learning_rate': 0.07611033527684935, 'num_leaves': 13, 'max_depth': 4, 'min_child_samples': 200, 'reg_alpha': 9, 'reg_lambda': 2, 'subsample': 0.9193212790298293, 'colsample_bytree': 0.6384647036359363}. Best is trial 0 with value: 0.9292895357302416.
# [I 2022-04-06 00:34:13,159] Trial 1 finished with value: 0.9295533584772588 and parameters: {'n_estimators': 950, 'learning_rate': 0.21585267618398365, 'num_leaves': 49, 'max_depth': 10, 'min_child_samples': 40, 'reg_alpha': 8, 'reg_lambda': 3, 'subsample': 0.7676992847745248, 'colsample_bytree': 0.6203806515495385}. Best is trial 1 with value: 0.9295533584772588.
# [I 2022-04-06 00:34:15,602] Trial 2 finished with value: 0.9272168710307586 and parameters: {'n_estimators': 350, 'learning_rate': 0.010306135216861296, 'num_leaves': 70, 'max_depth': 10, 'min_child_samples': 120, 'reg_alpha': 6, 'reg_lambda': 3, 'subsample': 0.657744027434324, 'colsample_bytree': 0.5922930953987231}. Best is trial 1 with value: 0.9295533584772588.
# [I 2022-04-06 00:34:17,606] Trial 3 finished with value: 0.9303809893346209 and parameters: {'n_estimators': 600, 'learning_rate': 0.04957544832220843, 'num_leaves': 46, 'max_depth': 9, 'min_child_samples': 140, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.9657144250701963, 'colsample_bytree': 0.566651745172914}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:20,390] Trial 4 finished with value: 0.9281777764108003 and parameters: {'n_estimators': 650, 'learning_rate': 0.045904322588299136, 'num_leaves': 31, 'max_depth': 10, 'min_child_samples': 160, 'reg_alpha': 7, 'reg_lambda': 10, 'subsample': 0.5493464629619612, 'colsample_bytree': 0.8716364633423399}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:20,433] Trial 5 pruned. Trial was pruned at iteration 4.
# [I 2022-04-06 00:34:21,384] Trial 6 finished with value: 0.9279495128801354 and parameters: {'n_estimators': 500, 'learning_rate': 0.3243059205771178, 'num_leaves': 19, 'max_depth': 6, 'min_child_samples': 100, 'reg_alpha': 2, 'reg_lambda': 2, 'subsample': 0.6382179931249061, 'colsample_bytree': 0.8958150434031822}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:21,420] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:21,460] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:21,497] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:22,968] Trial 10 finished with value: 0.9293277601757562 and parameters: {'n_estimators': 900, 'learning_rate': 0.11966239056140776, 'num_leaves': 53, 'max_depth': 8, 'min_child_samples': 20, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.9987593102383339, 'colsample_bytree': 0.5052085527310746}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:23,038] Trial 11 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:34:23,114] Trial 12 pruned. Trial was pruned at iteration 8.
# [I 2022-04-06 00:34:23,184] Trial 13 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:34:23,245] Trial 14 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:34:23,310] Trial 15 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:34:23,387] Trial 16 pruned. Trial was pruned at iteration 8.
# [I 2022-04-06 00:34:23,450] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:23,517] Trial 18 pruned. Trial was pruned at iteration 3.
# [I 2022-04-06 00:34:23,577] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:23,645] Trial 20 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:34:25,444] Trial 21 finished with value: 0.9300646690290097 and parameters: {'n_estimators': 950, 'learning_rate': 0.09795167277397301, 'num_leaves': 49, 'max_depth': 9, 'min_child_samples': 20, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.9632124709874329, 'colsample_bytree': 0.5071329736270316}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:25,516] Trial 22 pruned. Trial was pruned at iteration 6.
# [I 2022-04-06 00:34:26,916] Trial 23 finished with value: 0.9292386957897213 and parameters: {'n_estimators': 900, 'learning_rate': 0.16366006932875918, 'num_leaves': 39, 'max_depth': 7, 'min_child_samples': 20, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8468836042756184, 'colsample_bytree': 0.6186682084463611}. Best is trial 3 with value: 0.9303809893346209.
# [I 2022-04-06 00:34:26,975] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:27,064] Trial 25 pruned. Trial was pruned at iteration 15.
# [I 2022-04-06 00:34:27,123] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:27,183] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:34:27,247] Trial 28 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:34:27,307] Trial 29 pruned. Trial was pruned at iteration 0.

# %% [markdown]
# ## XGBoost

# %%
def xgb_objective(trial, X, y, oversampling=None, sampling_strategy=None, encoding='ohe'):
    
    #Param Grid for Lightgbm
    param_grid = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=50),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.5, log=True),
        #"num_leaves": trial.suggest_int("num_leaves", 2, 80),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 20, 200, step=20),
        "reg_alpha": trial.suggest_int("reg_alpha", 0, 10),
        "reg_lambda": trial.suggest_int("reg_lambda", 0, 10),
        #"min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1),
    }
    
    #Cross Validation with StratifiedKFold
    scores = []
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
    for train_idx, test_idx in cv.split(X, y):
        X_train_fold, X_test_fold = X.iloc[train_idx], X.iloc[test_idx]
        y_train_fold, y_test_fold = y[train_idx], y[test_idx]
        
        if oversampling == 'random':
            sampler = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=24)
            X_train_fold2, y_train_fold2 = sampler.fit_resample(X_train_fold, y_train_fold)
        elif oversampling == 'smote':
            categorical_features = np.array([idx for idx, col_name in enumerate(X_train_fold.columns) if col_name in cat_features])
            sampler = SMOTENC(categorical_features = categorical_features)
            X_train_fold2, y_train_fold2 = sampler.fit_resample(X_train_fold, y_train_fold)
        else:
            X_train_fold2, y_train_fold2 = X_train_fold, y_train_fold
        
        if encoding == 'ohe':
            cat_transformer = Pipeline(steps=[('encoder', OneHotEncoder(handle_unknown='ignore'))])
        elif encoding == 'te':
            cat_transformer = Pipeline(steps=[('encoder', TargetEncoder(min_samples_leaf=100, smoothing=5))])

        num_transformer = Pipeline(steps=[('identity', FunctionTransformer(func = None))])

        preprocessor = ColumnTransformer(transformers=[
                                                        ('num_trans', num_transformer, num_features),
                                                        ('cat_trans', cat_transformer, cat_features)
                                                    ],
                                        remainder='drop')

        xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                                  verbosity=0,
                                  random_state=24,
                                  tree_method="hist",
                                  enable_categorical=False,
                                  n_jobs=4, **param_grid)
        
        if oversampling == 'scale_pos_weight':
            ratio = sum(y_train_fold2 == 0) / sum(y_train_fold2 == 1)
            xgb_model.set_params(scale_pos_weight=ratio)

        clf = Pipeline(
            steps=[("preprocessor", preprocessor), ("classifier", xgb_model)]
        )

        clf.fit(X_train_fold2, y_train_fold2)
        
        y_preds_fold = clf.predict_proba(X_test_fold)
        y_preds_fold = [i[1] for i in y_preds_fold]
        fold_score = roc_auc_score(y_test_fold, y_preds_fold)
        scores.append(fold_score)
        
    return np.mean(scores)

# %% [markdown]
# ### SMOTENC

# %% [raw]
# study5 = optuna.create_study(direction="maximize", study_name="XGB")
# func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='smote', sampling_strategy='auto', encoding='ohe')
# study5.optimize(func, n_trials=20)

# %% [markdown]
# ### Random Over Sampling

# %%
study5 = optuna.create_study(direction="maximize", study_name="XGB2")
func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='random', sampling_strategy='auto', encoding='ohe')
study5.optimize(func, n_trials=20)
# Out:
# [I 2022-04-06 00:34:27,324] A new study created in memory with name: XGB2
# [I 2022-04-06 00:34:31,260] Trial 0 finished with value: 0.9289038404714443 and parameters: {'n_estimators': 350, 'learning_rate': 0.011303177735062907, 'max_depth': 8, 'min_child_weight': 20, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.5028423488175245, 'colsample_bytree': 0.5567674001059271}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:34,987] Trial 1 finished with value: 0.9250272030687885 and parameters: {'n_estimators': 500, 'learning_rate': 0.013603904162922698, 'max_depth': 4, 'min_child_weight': 40, 'reg_alpha': 0, 'reg_lambda': 8, 'subsample': 0.5617899294456232, 'colsample_bytree': 0.6029584233546259}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:38,816] Trial 2 finished with value: 0.9216338060882684 and parameters: {'n_estimators': 850, 'learning_rate': 0.032542110210141445, 'max_depth': 2, 'min_child_weight': 200, 'reg_alpha': 10, 'reg_lambda': 4, 'subsample': 0.6163025543537363, 'colsample_bytree': 0.876649692468572}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:41,575] Trial 3 finished with value: 0.9254234645110502 and parameters: {'n_estimators': 350, 'learning_rate': 0.15055421096191562, 'max_depth': 8, 'min_child_weight': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.5062512910738257, 'colsample_bytree': 0.5521545320225121}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:45,324] Trial 4 finished with value: 0.9246381451161028 and parameters: {'n_estimators': 550, 'learning_rate': 0.01829020489560677, 'max_depth': 5, 'min_child_weight': 180, 'reg_alpha': 2, 'reg_lambda': 5, 'subsample': 0.5075095110905383, 'colsample_bytree': 0.711503487420473}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:47,941] Trial 5 finished with value: 0.9218016572515368 and parameters: {'n_estimators': 250, 'learning_rate': 0.37544966986114187, 'max_depth': 10, 'min_child_weight': 140, 'reg_alpha': 3, 'reg_lambda': 9, 'subsample': 0.9825531676526451, 'colsample_bytree': 0.7932609587103194}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:53,313] Trial 6 finished with value: 0.9275389195646975 and parameters: {'n_estimators': 900, 'learning_rate': 0.03352975599125275, 'max_depth': 4, 'min_child_weight': 60, 'reg_alpha': 10, 'reg_lambda': 3, 'subsample': 0.7042458297101916, 'colsample_bytree': 0.8418196793643299}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:34:55,462] Trial 7 finished with value: 0.9262261715472622 and parameters: {'n_estimators': 150, 'learning_rate': 0.19086278396184073, 'max_depth': 7, 'min_child_weight': 20, 'reg_alpha': 7, 'reg_lambda': 9, 'subsample': 0.9786270531440993, 'colsample_bytree': 0.8235543667293882}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:00,987] Trial 8 finished with value: 0.9270719807854313 and parameters: {'n_estimators': 800, 'learning_rate': 0.018204492105599497, 'max_depth': 5, 'min_child_weight': 140, 'reg_alpha': 2, 'reg_lambda': 3, 'subsample': 0.6690045392177335, 'colsample_bytree': 0.5978795786377084}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:03,901] Trial 9 finished with value: 0.9209820496691332 and parameters: {'n_estimators': 400, 'learning_rate': 0.020023097012761292, 'max_depth': 4, 'min_child_weight': 200, 'reg_alpha': 5, 'reg_lambda': 8, 'subsample': 0.5357200746393045, 'colsample_bytree': 0.5802753170828293}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:05,821] Trial 10 finished with value: 0.9283405793708102 and parameters: {'n_estimators': 100, 'learning_rate': 0.06572964172139373, 'max_depth': 10, 'min_child_weight': 80, 'reg_alpha': 7, 'reg_lambda': 0, 'subsample': 0.8233135199304207, 'colsample_bytree': 0.9726237438798472}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:07,637] Trial 11 finished with value: 0.927943760892554 and parameters: {'n_estimators': 100, 'learning_rate': 0.07428358371889827, 'max_depth': 10, 'min_child_weight': 80, 'reg_alpha': 8, 'reg_lambda': 0, 'subsample': 0.8206197037346029, 'colsample_bytree': 0.9440575595281895}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:10,858] Trial 12 finished with value: 0.9280481682872445 and parameters: {'n_estimators': 300, 'learning_rate': 0.06152427509176396, 'max_depth': 8, 'min_child_weight': 100, 'reg_alpha': 7, 'reg_lambda': 1, 'subsample': 0.8170228374550877, 'colsample_bytree': 0.7084233693692805}. Best is trial 0 with value: 0.9289038404714443.
# [I 2022-04-06 00:35:18,877] Trial 13 finished with value: 0.9289790557042702 and parameters: {'n_estimators': 650, 'learning_rate': 0.011117104508941588, 'max_depth': 9, 'min_child_weight': 20, 'reg_alpha': 8, 'reg_lambda': 0, 'subsample': 0.82413898797011, 'colsample_bytree': 0.9841606857565495}. Best is trial 13 with value: 0.9289790557042702.
# [I 2022-04-06 00:35:25,901] Trial 14 finished with value: 0.9302515632640634 and parameters: {'n_estimators': 700, 'learning_rate': 0.01010318070706395, 'max_depth': 8, 'min_child_weight': 20, 'reg_alpha': 9, 'reg_lambda': 1, 'subsample': 0.8992653535247348, 'colsample_bytree': 0.5018749634600679}. Best is trial 14 with value: 0.9302515632640634.
# [I 2022-04-06 00:35:33,231] Trial 15 finished with value: 0.929535201728917 and parameters: {'n_estimators': 700, 'learning_rate': 0.010260039906363136, 'max_depth': 9, 'min_child_weight': 40, 'reg_alpha': 8, 'reg_lambda': 2, 'subsample': 0.9201865082080392, 'colsample_bytree': 0.678851543977023}. Best is trial 14 with value: 0.9302515632640634.
# [I 2022-04-06 00:35:39,063] Trial 16 finished with value: 0.9280869552984005 and parameters: {'n_estimators': 700, 'learning_rate': 0.03626617814329254, 'max_depth': 7, 'min_child_weight': 60, 'reg_alpha': 5, 'reg_lambda': 2, 'subsample': 0.9172398438851863, 'colsample_bytree': 0.5039423968416025}. Best is trial 14 with value: 0.9302515632640634.
# [I 2022-04-06 00:35:46,690] Trial 17 finished with value: 0.9286376319551245 and parameters: {'n_estimators': 750, 'learning_rate': 0.023891258948947672, 'max_depth': 9, 'min_child_weight': 40, 'reg_alpha': 9, 'reg_lambda': 5, 'subsample': 0.9148022521999286, 'colsample_bytree': 0.6651768534071408}. Best is trial 14 with value: 0.9302515632640634.
# [I 2022-04-06 00:35:55,059] Trial 18 finished with value: 0.9284715657133449 and parameters: {'n_estimators': 1000, 'learning_rate': 0.01067035066501921, 'max_depth': 7, 'min_child_weight': 60, 'reg_alpha': 8, 'reg_lambda': 2, 'subsample': 0.8977268312930066, 'colsample_bytree': 0.6588850840947963}. Best is trial 14 with value: 0.9302515632640634.
# [I 2022-04-06 00:36:00,313] Trial 19 finished with value: 0.9249719625013796 and parameters: {'n_estimators': 600, 'learning_rate': 0.1263205553113592, 'max_depth': 9, 'min_child_weight': 120, 'reg_alpha': 6, 'reg_lambda': 6, 'subsample': 0.7650857324523419, 'colsample_bytree': 0.5130868223966865}. Best is trial 14 with value: 0.9302515632640634.

# %%
study6 = optuna.create_study(direction="maximize", study_name="XGB3")
func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='random', sampling_strategy='auto', encoding='te')
study6.optimize(func, n_trials=20)
# Out:
# [I 2022-04-06 00:36:00,317] A new study created in memory with name: XGB3
# [I 2022-04-06 00:36:06,072] Trial 0 finished with value: 0.927096244269487 and parameters: {'n_estimators': 700, 'learning_rate': 0.05919113726546405, 'max_depth': 9, 'min_child_weight': 160, 'reg_alpha': 7, 'reg_lambda': 2, 'subsample': 0.6680632203954948, 'colsample_bytree': 0.8207287327475029}. Best is trial 0 with value: 0.927096244269487.
# [I 2022-04-06 00:36:13,298] Trial 1 finished with value: 0.9303721874731903 and parameters: {'n_estimators': 700, 'learning_rate': 0.018653841927448185, 'max_depth': 7, 'min_child_weight': 20, 'reg_alpha': 4, 'reg_lambda': 1, 'subsample': 0.523951982199114, 'colsample_bytree': 0.6908459205593644}. Best is trial 1 with value: 0.9303721874731903.
# [I 2022-04-06 00:36:19,618] Trial 2 finished with value: 0.9223304597178986 and parameters: {'n_estimators': 850, 'learning_rate': 0.2785353986807618, 'max_depth': 7, 'min_child_weight': 180, 'reg_alpha': 8, 'reg_lambda': 6, 'subsample': 0.5649109903953384, 'colsample_bytree': 0.6900902362668779}. Best is trial 1 with value: 0.9303721874731903.
# [I 2022-04-06 00:36:26,590] Trial 3 finished with value: 0.9277500385155116 and parameters: {'n_estimators': 950, 'learning_rate': 0.014741464972749174, 'max_depth': 9, 'min_child_weight': 180, 'reg_alpha': 10, 'reg_lambda': 5, 'subsample': 0.78066392174585, 'colsample_bytree': 0.5372353616855219}. Best is trial 1 with value: 0.9303721874731903.
# [I 2022-04-06 00:36:31,521] Trial 4 finished with value: 0.9249475915841794 and parameters: {'n_estimators': 700, 'learning_rate': 0.22444642197096853, 'max_depth': 3, 'min_child_weight': 100, 'reg_alpha': 0, 'reg_lambda': 9, 'subsample': 0.7493306909339621, 'colsample_bytree': 0.7656850853859427}. Best is trial 1 with value: 0.9303721874731903.
# [I 2022-04-06 00:36:35,078] Trial 5 finished with value: 0.9266400472247911 and parameters: {'n_estimators': 400, 'learning_rate': 0.040802173286035325, 'max_depth': 3, 'min_child_weight': 160, 'reg_alpha': 2, 'reg_lambda': 6, 'subsample': 0.7480360307575334, 'colsample_bytree': 0.9605806558868472}. Best is trial 1 with value: 0.9303721874731903.
# [I 2022-04-06 00:36:43,888] Trial 6 finished with value: 0.9310015064071377 and parameters: {'n_estimators': 1000, 'learning_rate': 0.01085683932685544, 'max_depth': 7, 'min_child_weight': 20, 'reg_alpha': 3, 'reg_lambda': 1, 'subsample': 0.5009186963118293, 'colsample_bytree': 0.7310016759193707}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:36:49,422] Trial 7 finished with value: 0.93022189233198 and parameters: {'n_estimators': 500, 'learning_rate': 0.02367788677232171, 'max_depth': 8, 'min_child_weight': 40, 'reg_alpha': 9, 'reg_lambda': 6, 'subsample': 0.6367807907053415, 'colsample_bytree': 0.9251895153265357}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:36:52,422] Trial 8 finished with value: 0.9227815346686661 and parameters: {'n_estimators': 150, 'learning_rate': 0.048071749336899415, 'max_depth': 8, 'min_child_weight': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.5043348466064437, 'colsample_bytree': 0.8337699863918061}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:36:56,425] Trial 9 finished with value: 0.9216538053636537 and parameters: {'n_estimators': 350, 'learning_rate': 0.2961810536775335, 'max_depth': 8, 'min_child_weight': 80, 'reg_alpha': 6, 'reg_lambda': 4, 'subsample': 0.6318982261503187, 'colsample_bytree': 0.6247220984136721}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:02,854] Trial 10 finished with value: 0.9239129220479491 and parameters: {'n_estimators': 950, 'learning_rate': 0.11112425617195903, 'max_depth': 5, 'min_child_weight': 60, 'reg_alpha': 4, 'reg_lambda': 0, 'subsample': 0.9769101991824033, 'colsample_bytree': 0.5187589950679676}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:08,886] Trial 11 finished with value: 0.9301378259570223 and parameters: {'n_estimators': 750, 'learning_rate': 0.01022172072423214, 'max_depth': 5, 'min_child_weight': 20, 'reg_alpha': 4, 'reg_lambda': 3, 'subsample': 0.5306914676549523, 'colsample_bytree': 0.6712602450099379}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:16,639] Trial 12 finished with value: 0.9288213297502971 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02110619561475295, 'max_depth': 6, 'min_child_weight': 20, 'reg_alpha': 2, 'reg_lambda': 0, 'subsample': 0.8815736655040456, 'colsample_bytree': 0.7459508103163653}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:23,203] Trial 13 finished with value: 0.9301562697608929 and parameters: {'n_estimators': 600, 'learning_rate': 0.01024872622822596, 'max_depth': 10, 'min_child_weight': 60, 'reg_alpha': 3, 'reg_lambda': 2, 'subsample': 0.5778101712353085, 'colsample_bytree': 0.6047374324037312}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:29,462] Trial 14 finished with value: 0.9276391017620746 and parameters: {'n_estimators': 850, 'learning_rate': 0.025124137006520313, 'max_depth': 6, 'min_child_weight': 120, 'reg_alpha': 0, 'reg_lambda': 9, 'subsample': 0.5064507728436575, 'colsample_bytree': 0.7297511094548707}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:34,412] Trial 15 finished with value: 0.9237411067960904 and parameters: {'n_estimators': 550, 'learning_rate': 0.11396690120652987, 'max_depth': 5, 'min_child_weight': 20, 'reg_alpha': 5, 'reg_lambda': 2, 'subsample': 0.596916083520461, 'colsample_bytree': 0.8235669755104603}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:41,008] Trial 16 finished with value: 0.9287730857056712 and parameters: {'n_estimators': 800, 'learning_rate': 0.01682005212606974, 'max_depth': 7, 'min_child_weight': 120, 'reg_alpha': 2, 'reg_lambda': 0, 'subsample': 0.6821422019894217, 'colsample_bytree': 0.614628258560711}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:44,417] Trial 17 finished with value: 0.9287276727796223 and parameters: {'n_estimators': 300, 'learning_rate': 0.0317299592099419, 'max_depth': 4, 'min_child_weight': 60, 'reg_alpha': 5, 'reg_lambda': 4, 'subsample': 0.8458367946732303, 'colsample_bytree': 0.8847321779002869}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:48,219] Trial 18 finished with value: 0.9275028077482222 and parameters: {'n_estimators': 650, 'learning_rate': 0.09130823447440958, 'max_depth': 2, 'min_child_weight': 40, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.5562409817279622, 'colsample_bytree': 0.6825971215309041}. Best is trial 6 with value: 0.9310015064071377.
# [I 2022-04-06 00:37:55,510] Trial 19 finished with value: 0.9295625665550761 and parameters: {'n_estimators': 900, 'learning_rate': 0.013085171830030985, 'max_depth': 7, 'min_child_weight': 100, 'reg_alpha': 4, 'reg_lambda': 8, 'subsample': 0.7139956023825665, 'colsample_bytree': 0.7763915994738113}. Best is trial 6 with value: 0.9310015064071377.

# %% [markdown]
# ### Scale Pos Weight Hyperparameter

# %%
study7 = optuna.create_study(direction="maximize", study_name="XGB4")
func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='scale_pos_weight', sampling_strategy='auto', encoding='ohe')
study7.optimize(func, n_trials=20)
# Out:
# [I 2022-04-06 00:37:55,514] A new study created in memory with name: XGB4
# [I 2022-04-06 00:37:59,210] Trial 0 finished with value: 0.9115083964495767 and parameters: {'n_estimators': 700, 'learning_rate': 0.3891090105687897, 'max_depth': 5, 'min_child_weight': 20, 'reg_alpha': 8, 'reg_lambda': 2, 'subsample': 0.7386163373160726, 'colsample_bytree': 0.6991921652858346}. Best is trial 0 with value: 0.9115083964495767.
# [I 2022-04-06 00:38:01,365] Trial 1 finished with value: 0.9259937009273591 and parameters: {'n_estimators': 600, 'learning_rate': 0.19924876332861402, 'max_depth': 3, 'min_child_weight': 180, 'reg_alpha': 0, 'reg_lambda': 3, 'subsample': 0.9353376275087812, 'colsample_bytree': 0.5527333575722869}. Best is trial 1 with value: 0.9259937009273591.
# [I 2022-04-06 00:38:05,699] Trial 2 finished with value: 0.9167242013084598 and parameters: {'n_estimators': 650, 'learning_rate': 0.22855225668152696, 'max_depth': 9, 'min_child_weight': 60, 'reg_alpha': 3, 'reg_lambda': 8, 'subsample': 0.9881303138427644, 'colsample_bytree': 0.5931071320782421}. Best is trial 1 with value: 0.9259937009273591.
# [I 2022-04-06 00:38:09,010] Trial 3 finished with value: 0.9274976896040418 and parameters: {'n_estimators': 750, 'learning_rate': 0.0725393711297546, 'max_depth': 4, 'min_child_weight': 20, 'reg_alpha': 6, 'reg_lambda': 10, 'subsample': 0.9271282953229706, 'colsample_bytree': 0.7426360190509631}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:11,616] Trial 4 finished with value: 0.9221427128234068 and parameters: {'n_estimators': 650, 'learning_rate': 0.23345911281936585, 'max_depth': 3, 'min_child_weight': 100, 'reg_alpha': 3, 'reg_lambda': 9, 'subsample': 0.6229531098849264, 'colsample_bytree': 0.761061779325952}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:14,425] Trial 5 finished with value: 0.9263943114067243 and parameters: {'n_estimators': 700, 'learning_rate': 0.03346304035988468, 'max_depth': 3, 'min_child_weight': 100, 'reg_alpha': 5, 'reg_lambda': 2, 'subsample': 0.7180809437622775, 'colsample_bytree': 0.9602606298856009}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:18,239] Trial 6 finished with value: 0.923405608215783 and parameters: {'n_estimators': 650, 'learning_rate': 0.15536905367827245, 'max_depth': 7, 'min_child_weight': 100, 'reg_alpha': 10, 'reg_lambda': 8, 'subsample': 0.8757142940201093, 'colsample_bytree': 0.5871479042635004}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:23,596] Trial 7 finished with value: 0.9238771622451656 and parameters: {'n_estimators': 1000, 'learning_rate': 0.09621135328675573, 'max_depth': 10, 'min_child_weight': 160, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.714779268497628, 'colsample_bytree': 0.6671862121214411}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:25,091] Trial 8 finished with value: 0.9189359538304455 and parameters: {'n_estimators': 400, 'learning_rate': 0.03118426973782561, 'max_depth': 2, 'min_child_weight': 140, 'reg_alpha': 10, 'reg_lambda': 2, 'subsample': 0.7018773794598117, 'colsample_bytree': 0.6852102352983094}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:30,116] Trial 9 finished with value: 0.9247654084262041 and parameters: {'n_estimators': 500, 'learning_rate': 0.06718334771292138, 'max_depth': 9, 'min_child_weight': 20, 'reg_alpha': 7, 'reg_lambda': 10, 'subsample': 0.8562748979556742, 'colsample_bytree': 0.6753572997927386}. Best is trial 3 with value: 0.9274976896040418.
# [I 2022-04-06 00:38:35,256] Trial 10 finished with value: 0.9284105820908616 and parameters: {'n_estimators': 900, 'learning_rate': 0.016045286125596803, 'max_depth': 6, 'min_child_weight': 60, 'reg_alpha': 6, 'reg_lambda': 6, 'subsample': 0.8341850363003334, 'colsample_bytree': 0.844577205433209}. Best is trial 10 with value: 0.9284105820908616.
# [I 2022-04-06 00:38:40,774] Trial 11 finished with value: 0.9286080992642199 and parameters: {'n_estimators': 950, 'learning_rate': 0.010664400130049165, 'max_depth': 6, 'min_child_weight': 60, 'reg_alpha': 6, 'reg_lambda': 6, 'subsample': 0.8467890576614695, 'colsample_bytree': 0.8519557602797069}. Best is trial 11 with value: 0.9286080992642199.
# [I 2022-04-06 00:38:47,152] Trial 12 finished with value: 0.9287203135484454 and parameters: {'n_estimators': 1000, 'learning_rate': 0.012053313046639107, 'max_depth': 7, 'min_child_weight': 60, 'reg_alpha': 4, 'reg_lambda': 5, 'subsample': 0.8219663514848952, 'colsample_bytree': 0.8825689344651058}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:38:48,331] Trial 13 finished with value: 0.917387212747105 and parameters: {'n_estimators': 100, 'learning_rate': 0.010558653034663907, 'max_depth': 7, 'min_child_weight': 60, 'reg_alpha': 3, 'reg_lambda': 5, 'subsample': 0.5073037065055137, 'colsample_bytree': 0.9044243039216797}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:38:54,229] Trial 14 finished with value: 0.9279318072537771 and parameters: {'n_estimators': 900, 'learning_rate': 0.02080363185426787, 'max_depth': 7, 'min_child_weight': 60, 'reg_alpha': 4, 'reg_lambda': 5, 'subsample': 0.8020427354647813, 'colsample_bytree': 0.8377041289203244}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:38:59,586] Trial 15 finished with value: 0.9280555050960061 and parameters: {'n_estimators': 1000, 'learning_rate': 0.010454759155867289, 'max_depth': 6, 'min_child_weight': 80, 'reg_alpha': 8, 'reg_lambda': 6, 'subsample': 0.7921276447472488, 'colsample_bytree': 0.8595529458994328}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:39:04,038] Trial 16 finished with value: 0.9270018466299204 and parameters: {'n_estimators': 850, 'learning_rate': 0.0318279514843453, 'max_depth': 8, 'min_child_weight': 140, 'reg_alpha': 2, 'reg_lambda': 4, 'subsample': 0.6330816209084646, 'colsample_bytree': 0.9953808507674992}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:39:05,931] Trial 17 finished with value: 0.9269811887188704 and parameters: {'n_estimators': 350, 'learning_rate': 0.01705870198057742, 'max_depth': 5, 'min_child_weight': 40, 'reg_alpha': 5, 'reg_lambda': 7, 'subsample': 0.9078344785989549, 'colsample_bytree': 0.9122744086669443}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:39:09,473] Trial 18 finished with value: 0.9276326530997174 and parameters: {'n_estimators': 800, 'learning_rate': 0.04733998757320842, 'max_depth': 5, 'min_child_weight': 200, 'reg_alpha': 1, 'reg_lambda': 4, 'subsample': 0.9930500536806294, 'colsample_bytree': 0.790570360013705}. Best is trial 12 with value: 0.9287203135484454.
# [I 2022-04-06 00:39:15,061] Trial 19 finished with value: 0.9277957191129417 and parameters: {'n_estimators': 1000, 'learning_rate': 0.021890659192491, 'max_depth': 8, 'min_child_weight': 120, 'reg_alpha': 8, 'reg_lambda': 0, 'subsample': 0.7915456022811864, 'colsample_bytree': 0.8990018484381}. Best is trial 12 with value: 0.9287203135484454.

# %%
study8 = optuna.create_study(direction="maximize", study_name="XGB5")
func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='scale_pos_weight', sampling_strategy='auto', encoding='te')
study8.optimize(func, n_trials=20)
# Out:
# [I 2022-04-06 00:39:15,068] A new study created in memory with name: XGB5
# [I 2022-04-06 00:39:17,369] Trial 0 finished with value: 0.9234098665302138 and parameters: {'n_estimators': 300, 'learning_rate': 0.22449649696630422, 'max_depth': 10, 'min_child_weight': 140, 'reg_alpha': 4, 'reg_lambda': 9, 'subsample': 0.7711324009330565, 'colsample_bytree': 0.8538418687409699}. Best is trial 0 with value: 0.9234098665302138.
# [I 2022-04-06 00:39:22,181] Trial 1 finished with value: 0.9291800978150102 and parameters: {'n_estimators': 800, 'learning_rate': 0.017238585114526733, 'max_depth': 9, 'min_child_weight': 120, 'reg_alpha': 7, 'reg_lambda': 0, 'subsample': 0.8407971711745343, 'colsample_bytree': 0.5572397143786367}. Best is trial 1 with value: 0.9291800978150102.
# [I 2022-04-06 00:39:26,272] Trial 2 finished with value: 0.9264455867917667 and parameters: {'n_estimators': 550, 'learning_rate': 0.05489470969045221, 'max_depth': 8, 'min_child_weight': 60, 'reg_alpha': 6, 'reg_lambda': 1, 'subsample': 0.8263576944518207, 'colsample_bytree': 0.7593156801910572}. Best is trial 1 with value: 0.9291800978150102.
# [I 2022-04-06 00:39:28,188] Trial 3 finished with value: 0.9212083033249712 and parameters: {'n_estimators': 150, 'learning_rate': 0.04144890372276479, 'max_depth': 4, 'min_child_weight': 200, 'reg_alpha': 8, 'reg_lambda': 10, 'subsample': 0.5568104315093183, 'colsample_bytree': 0.6609863724546456}. Best is trial 1 with value: 0.9291800978150102.
# [I 2022-04-06 00:39:32,277] Trial 4 finished with value: 0.9271363288639979 and parameters: {'n_estimators': 600, 'learning_rate': 0.05824881675653511, 'max_depth': 10, 'min_child_weight': 180, 'reg_alpha': 1, 'reg_lambda': 7, 'subsample': 0.9211020943169566, 'colsample_bytree': 0.7735700554264748}. Best is trial 1 with value: 0.9291800978150102.
# [I 2022-04-06 00:39:35,893] Trial 5 finished with value: 0.9291608271162112 and parameters: {'n_estimators': 850, 'learning_rate': 0.03222821615337878, 'max_depth': 3, 'min_child_weight': 40, 'reg_alpha': 4, 'reg_lambda': 0, 'subsample': 0.8736959512184248, 'colsample_bytree': 0.7011180452765191}. Best is trial 1 with value: 0.9291800978150102.
# [I 2022-04-06 00:39:39,821] Trial 6 finished with value: 0.9303988228720479 and parameters: {'n_estimators': 350, 'learning_rate': 0.022335833379850283, 'max_depth': 9, 'min_child_weight': 20, 'reg_alpha': 4, 'reg_lambda': 1, 'subsample': 0.7933483535585218, 'colsample_bytree': 0.8989748507545291}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:42,953] Trial 7 finished with value: 0.9275874683475704 and parameters: {'n_estimators': 750, 'learning_rate': 0.07560087532432445, 'max_depth': 3, 'min_child_weight': 160, 'reg_alpha': 8, 'reg_lambda': 1, 'subsample': 0.927973557899812, 'colsample_bytree': 0.7820349849615909}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:44,571] Trial 8 finished with value: 0.9206389092379904 and parameters: {'n_estimators': 100, 'learning_rate': 0.06969285461760935, 'max_depth': 3, 'min_child_weight': 200, 'reg_alpha': 0, 'reg_lambda': 6, 'subsample': 0.7227837112189801, 'colsample_bytree': 0.6154312538257631}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:47,087] Trial 9 finished with value: 0.926615048115368 and parameters: {'n_estimators': 700, 'learning_rate': 0.08249123755590707, 'max_depth': 2, 'min_child_weight': 100, 'reg_alpha': 3, 'reg_lambda': 10, 'subsample': 0.9356714429640733, 'colsample_bytree': 0.5786858848375809}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:50,608] Trial 10 finished with value: 0.9292680366444053 and parameters: {'n_estimators': 400, 'learning_rate': 0.010290443179587858, 'max_depth': 7, 'min_child_weight': 20, 'reg_alpha': 10, 'reg_lambda': 3, 'subsample': 0.6398482554914843, 'colsample_bytree': 0.9965508820601933}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:54,032] Trial 11 finished with value: 0.9295252515238394 and parameters: {'n_estimators': 400, 'learning_rate': 0.010889736566472494, 'max_depth': 7, 'min_child_weight': 20, 'reg_alpha': 10, 'reg_lambda': 3, 'subsample': 0.6444267796429041, 'colsample_bytree': 0.9845907423890943}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:56,992] Trial 12 finished with value: 0.926583218251046 and parameters: {'n_estimators': 400, 'learning_rate': 0.010662138573814036, 'max_depth': 6, 'min_child_weight': 80, 'reg_alpha': 10, 'reg_lambda': 3, 'subsample': 0.661993977461669, 'colsample_bytree': 0.9973702031314949}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:39:59,879] Trial 13 finished with value: 0.9300214146098421 and parameters: {'n_estimators': 300, 'learning_rate': 0.020721947456348953, 'max_depth': 6, 'min_child_weight': 20, 'reg_alpha': 2, 'reg_lambda': 3, 'subsample': 0.5107582931820347, 'colsample_bytree': 0.9120305739715143}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:04,744] Trial 14 finished with value: 0.9282575676393245 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02217822992738163, 'max_depth': 5, 'min_child_weight': 60, 'reg_alpha': 2, 'reg_lambda': 4, 'subsample': 0.5201434129709965, 'colsample_bytree': 0.894726583773238}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:07,062] Trial 15 finished with value: 0.9246546725630255 and parameters: {'n_estimators': 200, 'learning_rate': 0.1430100870082249, 'max_depth': 6, 'min_child_weight': 20, 'reg_alpha': 2, 'reg_lambda': 2, 'subsample': 0.7421593626459708, 'colsample_bytree': 0.910842316534234}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:09,804] Trial 16 finished with value: 0.9289183141101895 and parameters: {'n_estimators': 250, 'learning_rate': 0.022288794055460897, 'max_depth': 8, 'min_child_weight': 60, 'reg_alpha': 5, 'reg_lambda': 6, 'subsample': 0.5723242252951559, 'colsample_bytree': 0.8461944657933239}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:12,910] Trial 17 finished with value: 0.9288830112020978 and parameters: {'n_estimators': 500, 'learning_rate': 0.03254212566083048, 'max_depth': 5, 'min_child_weight': 100, 'reg_alpha': 0, 'reg_lambda': 5, 'subsample': 0.791796960338389, 'colsample_bytree': 0.9304286535609438}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:16,090] Trial 18 finished with value: 0.9125485631842615 and parameters: {'n_estimators': 350, 'learning_rate': 0.42592090523882464, 'max_depth': 8, 'min_child_weight': 40, 'reg_alpha': 3, 'reg_lambda': 2, 'subsample': 0.9939065771843354, 'colsample_bytree': 0.83653840890498}. Best is trial 6 with value: 0.9303988228720479.
# [I 2022-04-06 00:40:20,489] Trial 19 finished with value: 0.9299931468105326 and parameters: {'n_estimators': 500, 'learning_rate': 0.016250691655236668, 'max_depth': 9, 'min_child_weight': 40, 'reg_alpha': 5, 'reg_lambda': 4, 'subsample': 0.6707515078052352, 'colsample_bytree': 0.9440697791965735}. Best is trial 6 with value: 0.9303988228720479.

# %% [raw]
# study.trials_dataframe().sort_values('value', ascending=False).head()

# %%
study2.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 9        9  0.930788 2022-04-06 00:33:47.548073 2022-04-06 00:33:48.961537
# 0        0  0.930655 2022-04-06 00:33:24.635896 2022-04-06 00:33:28.317679
# 4        4  0.930526 2022-04-06 00:33:37.654765 2022-04-06 00:33:43.456320
# 2        2  0.930292 2022-04-06 00:33:30.812216 2022-04-06 00:33:34.065994
# 12      12  0.929875 2022-04-06 00:33:49.230851 2022-04-06 00:33:51.485716
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 9  0 days 00:00:01.413464                 0.702969              0.113336
# 0  0 days 00:00:03.681783                 0.784371              0.023392
# 4  0 days 00:00:05.801555                 0.550079              0.010962
# 2  0 days 00:00:03.253778                 0.759230              0.047033
# 12 0 days 00:00:02.254865                 0.835580              0.024971
#
#     params_max_depth  params_min_child_samples  params_n_estimators  \
# 9                  7                        80                  100
# 0                  7                       140                  900
# 4                  8                        20                  550
# 2                  4                       120                  600
# 12                 7                       140                  150
#
#     params_num_leaves  params_reg_alpha  params_reg_lambda  params_subsample  \
# 9                  19                 4                  0          0.517086
# 0                  40                 4                  2          0.959862
# 4                  27                 1                  5          0.584831
# 2                  78                 2                 10          0.646684
# 12                 43                 0                  4          0.835491
#
#        state
# 9   COMPLETE
# 0   COMPLETE
# 4   COMPLETE
# 2   COMPLETE
# 12  COMPLETE

# %%
study3.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 1       1  0.930663 2022-04-06 00:33:55.446239 2022-04-06 00:34:01.646298
# 3       3  0.930184 2022-04-06 00:34:03.302571 2022-04-06 00:34:04.888609
# 2       2  0.928452 2022-04-06 00:34:01.648541 2022-04-06 00:34:03.300272
# 9       9  0.928345 2022-04-06 00:34:07.142702 2022-04-06 00:34:08.348934
# 4       4  0.928149 2022-04-06 00:34:04.890898 2022-04-06 00:34:06.977506
#
#                 duration  params_colsample_bytree  params_learning_rate  \
# 1 0 days 00:00:06.200059                 0.783998              0.010265
# 3 0 days 00:00:01.586038                 0.802013              0.060831
# 2 0 days 00:00:01.651731                 0.842030              0.241255
# 9 0 days 00:00:01.206232                 0.784923              0.174732
# 4 0 days 00:00:02.086608                 0.821158              0.093380
#
#    params_max_depth  params_min_child_samples  params_n_estimators  \
# 1                10                        20                  800
# 3                 7                       100                  200
# 2                 2                       200                  800
# 9                10                       100                  650
# 4                 3                       120                  700
#
#    params_num_leaves  params_reg_alpha  params_reg_lambda  params_subsample  \
# 1                 36                 5                  5          0.729973
# 3                 46                 3                  6          0.657514
# 2                 64                 9                  3          0.813289
# 9                 34                 6                  0          0.589694
# 4                 59                 5                  5          0.516294
#
#       state
# 1  COMPLETE
# 3  COMPLETE
# 2  COMPLETE
# 9  COMPLETE
# 4  COMPLETE

# %%
study4.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 3        3  0.930381 2022-04-06 00:34:15.602871 2022-04-06 00:34:17.606085
# 21      21  0.930065 2022-04-06 00:34:23.646507 2022-04-06 00:34:25.444241
# 1        1  0.929553 2022-04-06 00:34:11.978375 2022-04-06 00:34:13.158639
# 10      10  0.929328 2022-04-06 00:34:21.498321 2022-04-06 00:34:22.967818
# 0        0  0.929290 2022-04-06 00:34:10.787671 2022-04-06 00:34:11.977167
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 3  0 days 00:00:02.003214                 0.566652              0.049575
# 21 0 days 00:00:01.797734                 0.507133              0.097952
# 1  0 days 00:00:01.180264                 0.620381              0.215853
# 10 0 days 00:00:01.469497                 0.505209              0.119662
# 0  0 days 00:00:01.189496                 0.638465              0.076110
#
#     params_max_depth  params_min_child_samples  params_n_estimators  \
# 3                  9                       140                  600
# 21                 9                        20                  950
# 1                 10                        40                  950
# 10                 8                        20                  900
# 0                  4                       200                  200
#
#     params_num_leaves  params_reg_alpha  params_reg_lambda  params_subsample  \
# 3                  46                 0                  0          0.965714
# 21                 49                 0                  0          0.963212
# 1                  49                 8                  3          0.767699
# 10                 53                 0                  0          0.998759
# 0                  13                 9                  2          0.919321
#
#        state
# 3   COMPLETE
# 21  COMPLETE
# 1   COMPLETE
# 10  COMPLETE
# 0   COMPLETE

# %%
study5.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 14      14  0.930252 2022-04-06 00:35:18.878931 2022-04-06 00:35:25.901497
# 15      15  0.929535 2022-04-06 00:35:25.902373 2022-04-06 00:35:33.230988
# 13      13  0.928979 2022-04-06 00:35:10.859412 2022-04-06 00:35:18.877498
# 0        0  0.928904 2022-04-06 00:34:27.326309 2022-04-06 00:34:31.260466
# 17      17  0.928638 2022-04-06 00:35:39.064149 2022-04-06 00:35:46.690530
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 14 0 days 00:00:07.022566                 0.501875              0.010103
# 15 0 days 00:00:07.328615                 0.678852              0.010260
# 13 0 days 00:00:08.018086                 0.984161              0.011117
# 0  0 days 00:00:03.934157                 0.556767              0.011303
# 17 0 days 00:00:07.626381                 0.665177              0.023891
#
#     params_max_depth  params_min_child_weight  params_n_estimators  \
# 14                 8                       20                  700
# 15                 9                       40                  700
# 13                 9                       20                  650
# 0                  8                       20                  350
# 17                 9                       40                  750
#
#     params_reg_alpha  params_reg_lambda  params_subsample     state
# 14                 9                  1          0.899265  COMPLETE
# 15                 8                  2          0.920187  COMPLETE
# 13                 8                  0          0.824139  COMPLETE
# 0                 10                  0          0.502842  COMPLETE
# 17                 9                  5          0.914802  COMPLETE

# %%
study6.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 6        6  0.931002 2022-04-06 00:36:35.079078 2022-04-06 00:36:43.888369
# 1        1  0.930372 2022-04-06 00:36:06.073419 2022-04-06 00:36:13.298210
# 7        7  0.930222 2022-04-06 00:36:43.889272 2022-04-06 00:36:49.422064
# 13      13  0.930156 2022-04-06 00:37:16.639729 2022-04-06 00:37:23.203474
# 11      11  0.930138 2022-04-06 00:37:02.855776 2022-04-06 00:37:08.886219
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 6  0 days 00:00:08.809291                 0.731002              0.010857
# 1  0 days 00:00:07.224791                 0.690846              0.018654
# 7  0 days 00:00:05.532792                 0.925190              0.023678
# 13 0 days 00:00:06.563745                 0.604737              0.010249
# 11 0 days 00:00:06.030443                 0.671260              0.010222
#
#     params_max_depth  params_min_child_weight  params_n_estimators  \
# 6                  7                       20                 1000
# 1                  7                       20                  700
# 7                  8                       40                  500
# 13                10                       60                  600
# 11                 5                       20                  750
#
#     params_reg_alpha  params_reg_lambda  params_subsample     state
# 6                  3                  1          0.500919  COMPLETE
# 1                  4                  1          0.523952  COMPLETE
# 7                  9                  6          0.636781  COMPLETE
# 13                 3                  2          0.577810  COMPLETE
# 11                 4                  3          0.530691  COMPLETE

# %%
study7.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 12      12  0.928720 2022-04-06 00:38:40.775707 2022-04-06 00:38:47.152131
# 11      11  0.928608 2022-04-06 00:38:35.257968 2022-04-06 00:38:40.774401
# 10      10  0.928411 2022-04-06 00:38:30.117211 2022-04-06 00:38:35.256563
# 15      15  0.928056 2022-04-06 00:38:54.230882 2022-04-06 00:38:59.585874
# 14      14  0.927932 2022-04-06 00:38:48.331678 2022-04-06 00:38:54.229591
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 12 0 days 00:00:06.376424                 0.882569              0.012053
# 11 0 days 00:00:05.516433                 0.851956              0.010664
# 10 0 days 00:00:05.139352                 0.844577              0.016045
# 15 0 days 00:00:05.354992                 0.859553              0.010455
# 14 0 days 00:00:05.897913                 0.837704              0.020804
#
#     params_max_depth  params_min_child_weight  params_n_estimators  \
# 12                 7                       60                 1000
# 11                 6                       60                  950
# 10                 6                       60                  900
# 15                 6                       80                 1000
# 14                 7                       60                  900
#
#     params_reg_alpha  params_reg_lambda  params_subsample     state
# 12                 4                  5          0.821966  COMPLETE
# 11                 6                  6          0.846789  COMPLETE
# 10                 6                  6          0.834185  COMPLETE
# 15                 8                  6          0.792128  COMPLETE
# 14                 4                  5          0.802043  COMPLETE

# %%
study8.trials_dataframe().sort_values('value', ascending=False).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 6        6  0.930399 2022-04-06 00:39:35.894099 2022-04-06 00:39:39.821185
# 13      13  0.930021 2022-04-06 00:39:56.993204 2022-04-06 00:39:59.879292
# 19      19  0.929993 2022-04-06 00:40:16.091291 2022-04-06 00:40:20.489433
# 11      11  0.929525 2022-04-06 00:39:50.608895 2022-04-06 00:39:54.032009
# 10      10  0.929268 2022-04-06 00:39:47.088138 2022-04-06 00:39:50.608011
#
#                  duration  params_colsample_bytree  params_learning_rate  \
# 6  0 days 00:00:03.927086                 0.898975              0.022336
# 13 0 days 00:00:02.886088                 0.912031              0.020722
# 19 0 days 00:00:04.398142                 0.944070              0.016251
# 11 0 days 00:00:03.423114                 0.984591              0.010890
# 10 0 days 00:00:03.519873                 0.996551              0.010290
#
#     params_max_depth  params_min_child_weight  params_n_estimators  \
# 6                  9                       20                  350
# 13                 6                       20                  300
# 19                 9                       40                  500
# 11                 7                       20                  400
# 10                 7                       20                  400
#
#     params_reg_alpha  params_reg_lambda  params_subsample     state
# 6                  4                  1          0.793348  COMPLETE
# 13                 2                  3          0.510758  COMPLETE
# 19                 5                  4          0.670752  COMPLETE
# 11                10                  3          0.644427  COMPLETE
# 10                10                  3          0.639848  COMPLETE

# %% [markdown]
# # Remove Unimportant Features

# %%
feature_set = ['age', 'job', 'education', 'default',
               'contact', 'month', 'day_of_week', 'duration', 'campaign', 'previous',
               'poutcome', 'quarter']

cat_features = ['job', 'education', 'default',
                'contact', 'month', 'day_of_week', 'poutcome', 'quarter']

num_features = ['age', 'duration', 'campaign', 'previous']

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data[feature_set], train_data.y_encoded, random_state=24, test_size=0.2)

# %%
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
X_train.shape, X_test.shape
# Out:
# ((26328, 12), (6582, 12))

# %% [markdown]
# ### Class Weight Hyperparameter

# %%
study9 = optuna.create_study(direction="maximize", study_name="LGBM2")
func = lambda trial: lgbm_objective(trial, X_train, y_train, oversampling='random', sampling_strategy='auto')
study9.optimize(func, n_trials=30)
# Out:
# [I 2022-04-06 00:10:17,509] A new study created in memory with name: LGBM2
# [I 2022-04-06 00:10:19,705] Trial 0 finished with value: 0.931183266152131 and parameters: {'n_estimators': 650, 'learning_rate': 0.04931774162043972, 'num_leaves': 33, 'max_depth': 9, 'min_child_samples': 180, 'lambda_l1': 1, 'lambda_l2': 7, 'bagging_fraction': 0.8485786057147204, 'feature_fraction': 0.7874396169748645}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:21,136] Trial 1 finished with value: 0.9287072657687162 and parameters: {'n_estimators': 200, 'learning_rate': 0.3709933931371577, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 180, 'lambda_l1': 6, 'lambda_l2': 6, 'bagging_fraction': 0.6919072490940053, 'feature_fraction': 0.8776327511292803}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:23,026] Trial 2 finished with value: 0.9298785495522109 and parameters: {'n_estimators': 350, 'learning_rate': 0.1092847951220914, 'num_leaves': 53, 'max_depth': 4, 'min_child_samples': 80, 'lambda_l1': 1, 'lambda_l2': 6, 'bagging_fraction': 0.8814707184193323, 'feature_fraction': 0.8854093529464988}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:24,873] Trial 3 finished with value: 0.9306084086522318 and parameters: {'n_estimators': 700, 'learning_rate': 0.16090408822651522, 'num_leaves': 9, 'max_depth': 4, 'min_child_samples': 80, 'lambda_l1': 9, 'lambda_l2': 4, 'bagging_fraction': 0.5331323143697566, 'feature_fraction': 0.7296160242807279}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:27,994] Trial 4 finished with value: 0.9303953093585529 and parameters: {'n_estimators': 400, 'learning_rate': 0.03875352981973712, 'num_leaves': 18, 'max_depth': 4, 'min_child_samples': 180, 'lambda_l1': 5, 'lambda_l2': 6, 'bagging_fraction': 0.56736200497105, 'feature_fraction': 0.6703293457041788}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:28,071] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:28,150] Trial 6 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:10:28,224] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:28,293] Trial 8 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:28,369] Trial 9 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:10:30,315] Trial 10 finished with value: 0.9299142199083942 and parameters: {'n_estimators': 1000, 'learning_rate': 0.09001299088610809, 'num_leaves': 36, 'max_depth': 10, 'min_child_samples': 20, 'lambda_l1': 0, 'lambda_l2': 0, 'bagging_fraction': 0.979201728950517, 'feature_fraction': 0.9890133229765254}. Best is trial 0 with value: 0.931183266152131.
# [I 2022-04-06 00:10:30,423] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:30,525] Trial 12 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:30,627] Trial 13 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:30,731] Trial 14 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:30,835] Trial 15 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:10:30,939] Trial 16 pruned. Trial was pruned at iteration 2.
# [I 2022-04-06 00:10:31,040] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,146] Trial 18 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,260] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,366] Trial 20 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:10:31,464] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,557] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,652] Trial 23 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,755] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:31,850] Trial 25 pruned. Trial was pruned at iteration 1.
# [I 2022-04-06 00:10:31,940] Trial 26 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:32,031] Trial 27 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:32,126] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2022-04-06 00:10:32,215] Trial 29 pruned. Trial was pruned at iteration 0.

# %%
study10 = optuna.create_study(direction="maximize", study_name="XGB5")
func = lambda trial: xgb_objective(trial, X_train, y_train, oversampling='scale_pos_weight', sampling_strategy='auto', encoding='te')
study10.optimize(func, n_trials=20)
# Out:
# [I 2022-04-06 00:10:32,222] A new study created in memory with name: XGB5
# [I 2022-04-06 00:10:35,914] Trial 0 finished with value: 0.9270831346306279 and parameters: {'n_estimators': 850, 'learning_rate': 0.020232226927244988, 'max_depth': 9, 'min_child_weight': 200, 'lambda_l1': 2, 'lambda_l2': 6, 'bagging_fraction': 0.7803286942701633, 'feature_fraction': 0.6335309117627896}. Best is trial 0 with value: 0.9270831346306279.
# [I 2022-04-06 00:10:38,690] Trial 1 finished with value: 0.9244866813356174 and parameters: {'n_estimators': 900, 'learning_rate': 0.03077675866683733, 'max_depth': 3, 'min_child_weight': 200, 'lambda_l1': 1, 'lambda_l2': 2, 'bagging_fraction': 0.5565174947607294, 'feature_fraction': 0.8826024552349538}. Best is trial 0 with value: 0.9270831346306279.
# [I 2022-04-06 00:10:40,681] Trial 2 finished with value: 0.9271019274099228 and parameters: {'n_estimators': 600, 'learning_rate': 0.1158026367351804, 'max_depth': 2, 'min_child_weight': 20, 'lambda_l1': 4, 'lambda_l2': 5, 'bagging_fraction': 0.519738745109336, 'feature_fraction': 0.742975848988155}. Best is trial 2 with value: 0.9271019274099228.
# [I 2022-04-06 00:10:42,774] Trial 3 finished with value: 0.9294500248671269 and parameters: {'n_estimators': 500, 'learning_rate': 0.08458136554579704, 'max_depth': 4, 'min_child_weight': 40, 'lambda_l1': 10, 'lambda_l2': 6, 'bagging_fraction': 0.9106876469662519, 'feature_fraction': 0.5956258102343621}. Best is trial 3 with value: 0.9294500248671269.
# [I 2022-04-06 00:10:47,238] Trial 4 finished with value: 0.929278393551993 and parameters: {'n_estimators': 1000, 'learning_rate': 0.019917481882079622, 'max_depth': 8, 'min_child_weight': 120, 'lambda_l1': 10, 'lambda_l2': 7, 'bagging_fraction': 0.9070040612289647, 'feature_fraction': 0.6759791763150034}. Best is trial 3 with value: 0.9294500248671269.
# [I 2022-04-06 00:10:48,800] Trial 5 finished with value: 0.9273263436430067 and parameters: {'n_estimators': 200, 'learning_rate': 0.10333631676436794, 'max_depth': 7, 'min_child_weight': 140, 'lambda_l1': 1, 'lambda_l2': 8, 'bagging_fraction': 0.7257613884794287, 'feature_fraction': 0.9409536434131103}. Best is trial 3 with value: 0.9294500248671269.
# [I 2022-04-06 00:10:50,730] Trial 6 finished with value: 0.9242286548133588 and parameters: {'n_estimators': 600, 'learning_rate': 0.402720230741225, 'max_depth': 2, 'min_child_weight': 80, 'lambda_l1': 10, 'lambda_l2': 0, 'bagging_fraction': 0.5812302708948691, 'feature_fraction': 0.8570175797997573}. Best is trial 3 with value: 0.9294500248671269.
# [I 2022-04-06 00:10:54,018] Trial 7 finished with value: 0.9313639667570156 and parameters: {'n_estimators': 300, 'learning_rate': 0.0111674757049793, 'max_depth': 10, 'min_child_weight': 20, 'lambda_l1': 0, 'lambda_l2': 2, 'bagging_fraction': 0.8313076359586836, 'feature_fraction': 0.7182130284177133}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:10:55,654] Trial 8 finished with value: 0.9253887423374405 and parameters: {'n_estimators': 450, 'learning_rate': 0.4594726175670671, 'max_depth': 2, 'min_child_weight': 120, 'lambda_l1': 2, 'lambda_l2': 0, 'bagging_fraction': 0.7679410420735975, 'feature_fraction': 0.8771640729066497}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:10:58,030] Trial 9 finished with value: 0.9277456447551081 and parameters: {'n_estimators': 950, 'learning_rate': 0.2009659495248562, 'max_depth': 2, 'min_child_weight': 60, 'lambda_l1': 9, 'lambda_l2': 0, 'bagging_fraction': 0.9977589965196977, 'feature_fraction': 0.6363929085090405}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:10:59,308] Trial 10 finished with value: 0.9246838604713152 and parameters: {'n_estimators': 100, 'learning_rate': 0.011803985962094875, 'max_depth': 10, 'min_child_weight': 80, 'lambda_l1': 6, 'lambda_l2': 10, 'bagging_fraction': 0.7026251920289563, 'feature_fraction': 0.5127271193950134}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:01,257] Trial 11 finished with value: 0.9306072011838958 and parameters: {'n_estimators': 350, 'learning_rate': 0.048957855771131556, 'max_depth': 5, 'min_child_weight': 20, 'lambda_l1': 7, 'lambda_l2': 4, 'bagging_fraction': 0.8782186483494786, 'feature_fraction': 0.5265651012555581}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:03,034] Trial 12 finished with value: 0.9309187277715477 and parameters: {'n_estimators': 300, 'learning_rate': 0.03785898201498005, 'max_depth': 5, 'min_child_weight': 20, 'lambda_l1': 7, 'lambda_l2': 3, 'bagging_fraction': 0.8572981290533969, 'feature_fraction': 0.5106600641825261}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:04,843] Trial 13 finished with value: 0.9276966347024379 and parameters: {'n_estimators': 250, 'learning_rate': 0.010737536210809702, 'max_depth': 6, 'min_child_weight': 60, 'lambda_l1': 4, 'lambda_l2': 3, 'bagging_fraction': 0.8392114984277846, 'feature_fraction': 0.7554012575289675}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:07,214] Trial 14 finished with value: 0.9302518193292626 and parameters: {'n_estimators': 350, 'learning_rate': 0.040164569437943755, 'max_depth': 6, 'min_child_weight': 20, 'lambda_l1': 7, 'lambda_l2': 2, 'bagging_fraction': 0.6422332592173147, 'feature_fraction': 0.767844436173954}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:11,200] Trial 15 finished with value: 0.9292001668490212 and parameters: {'n_estimators': 700, 'learning_rate': 0.020385934623554234, 'max_depth': 10, 'min_child_weight': 160, 'lambda_l1': 0, 'lambda_l2': 2, 'bagging_fraction': 0.9984571413797693, 'feature_fraction': 0.5691666871537759}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:13,805] Trial 16 finished with value: 0.9293935725170421 and parameters: {'n_estimators': 350, 'learning_rate': 0.05397905590467354, 'max_depth': 8, 'min_child_weight': 60, 'lambda_l1': 8, 'lambda_l2': 4, 'bagging_fraction': 0.8311015384890167, 'feature_fraction': 0.6996168462653763}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:15,127] Trial 17 finished with value: 0.930099436655104 and parameters: {'n_estimators': 100, 'learning_rate': 0.17397466513550644, 'max_depth': 5, 'min_child_weight': 40, 'lambda_l1': 5, 'lambda_l2': 3, 'bagging_fraction': 0.9389220344730433, 'feature_fraction': 0.820281161307975}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:16,824] Trial 18 finished with value: 0.927311462329506 and parameters: {'n_estimators': 250, 'learning_rate': 0.027575325440597803, 'max_depth': 4, 'min_child_weight': 100, 'lambda_l1': 4, 'lambda_l2': 1, 'bagging_fraction': 0.8353774344959272, 'feature_fraction': 0.945581766256157}. Best is trial 7 with value: 0.9313639667570156.
# [I 2022-04-06 00:11:21,181] Trial 19 finished with value: 0.9308358934748938 and parameters: {'n_estimators': 750, 'learning_rate': 0.010439410240505868, 'max_depth': 7, 'min_child_weight': 40, 'lambda_l1': 6, 'lambda_l2': 4, 'bagging_fraction': 0.6640625761471873, 'feature_fraction': 0.5727240672510172}. Best is trial 7 with value: 0.9313639667570156.

# %%
study6.trials_dataframe().sort_values('value', ascending=False).iloc[0].to_dict()
# Out:
# {'number': 6,
#  'value': 0.9310015064071377,
#  'datetime_start': Timestamp('2022-04-06 00:36:35.079078'),
#  'datetime_complete': Timestamp('2022-04-06 00:36:43.888369'),
#  'duration': Timedelta('0 days 00:00:08.809291'),
#  'params_colsample_bytree': 0.7310016759193707,
#  'params_learning_rate': 0.01085683932685544,
#  'params_max_depth': 7,
#  'params_min_child_weight': 20,
#  'params_n_estimators': 1000,
#  'params_reg_alpha': 3,
#  'params_reg_lambda': 1,
#  'params_subsample': 0.5009186963118293,
#  'state': 'COMPLETE'}
